# %%
import pandas as pd

# %%
file_path = r'S:\Project_Data\WEL-2101\new_structures.csv'

df_csv = pd.read_csv(file_path)

df_csv
# Out:
#    Point    Flowline    Easting    Northing     kp  node_id abbreviation  \
# 0   FLET  PR-N-FL-01  226022.41  1519349.94      2        3       SNENF1
# 1    ILS  PR-N-FL-01  219875.46  1522369.07   7867     7868       SNENF1
# 2    ILT  PR-N-FL-01  219152.57  1522314.36   8592     8593       SNENF1
# 3    ILT  PR-N-FL-01  217597.95  1523051.99  10410    10411       SNENF1
# 4   FLET  PR-N-FL-01  216438.25  1524217.00  12054   101412       SNENF1
# 5   FLET  PR-N-FL-02  225941.03  1519328.39      2    12031       SNENF2
# 6    ILT  PR-N-FL-02  219128.24  1522292.47   8539    20568       SNENF2
# 7    ILT  PR-N-FL-02  217565.49  1523056.25  10383    22412       SNENF2
# 8   FLET  PR-N-FL-02  216463.25  1524163.53  11946   101427       SNENF2
# 9   FLET  WI-N-FL-01  225970.78  1519654.03      2    35460     SNENWIF1
# 10   ILT  WI-N-FL-01  221398.40  1522606.92   6114    41572     SNENWIF1
# 11  FLET  WI-N-FL-01  219060.43  1522518.09   8454   101781     SNENWIF1
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Point           44 non-null     object
#  1   Flowline        44 non-null     object
#  2   Easting         44 non-null     float64
#  3   Northing        44 non-null     float64
#  4   kp              44 non-null     int64
#  5   node_id         44 non-null     int64
#  6   abbreviation    44 non-null     object
#  7   structure_name  44 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
missing_values = df_csv.isnull().sum()
print(missing_values)
# Out:
# Point             0
# Flowline          0
# Easting           0
# Northing          0
# kp                0
# node_id           0
# abbreviation      0
# structure_name    0
# dtype: int64

# %%
df_csv['Point'] == 'ILT'
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21    False
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27     True
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# 40    False
# 41    False
# 42     True
# 43    False
# Name: Point, dtype: bool

# %%
filtered_df = df_csv[df_csv['Point'] == 'ILT']
filtered_df
# Out:
#    Point    Flowline    Easting    Northing     kp  node_id abbreviation  \
# 2    ILT  PR-N-FL-01  219152.57  1522314.36   8592     8593       SNENF1
# 3    ILT  PR-N-FL-01  217597.95  1523051.99  10410    10411       SNENF1
# 6    ILT  PR-N-FL-02  219128.24  1522292.47   8539    20568       SNENF2
# 7    ILT  PR-N-FL-02  217565.49  1523056.25  10383    22412       SNENF2
# 10   ILT  WI-N-FL-01  221398.40  1522606.92   6114    41572     SNENWIF1
# 13   ILT  GL-N-FL-01  219706.00  1522276.01   7468    31441     SNENGLF1
# 14   ILT  GL-N-FL-01  218983.10  1522221.31   8193    32166     SNENGLF1
# 15   ILT  GL-N-FL-01  217612.87  1522902.34   9826    33799     SNENGLF1
# 18   ILT  PR-S-FL-01  217864.79  1517979.36   8476    52383       SNESF1
# 19   ILT  PR-S-FL-01  217293.21  1518539.23   9276    53183       SNESF1
# 22   ILT  PR-S-FL-02  223860.53  1516936.31   1418    57863       SNESF2
# 23   ILT  PR-S-FL-02  222721.73  1516058.29   2855    59300       SNESF2
# ...

# %%
len(df_csv) - len(filtered_df)
# Out:
# 20

# %%
df_csv.rename(columns={'structure_name': 'name'}, inplace=True)
df_csv
# Out:
#    Point    Flowline    Easting    Northing     kp  node_id abbreviation  \
# 0   FLET  PR-N-FL-01  226022.41  1519349.94      2        3       SNENF1
# 1    ILS  PR-N-FL-01  219875.46  1522369.07   7867     7868       SNENF1
# 2    ILT  PR-N-FL-01  219152.57  1522314.36   8592     8593       SNENF1
# 3    ILT  PR-N-FL-01  217597.95  1523051.99  10410    10411       SNENF1
# 4   FLET  PR-N-FL-01  216438.25  1524217.00  12054   101412       SNENF1
# 5   FLET  PR-N-FL-02  225941.03  1519328.39      2    12031       SNENF2
# 6    ILT  PR-N-FL-02  219128.24  1522292.47   8539    20568       SNENF2
# 7    ILT  PR-N-FL-02  217565.49  1523056.25  10383    22412       SNENF2
# 8   FLET  PR-N-FL-02  216463.25  1524163.53  11946   101427       SNENF2
# 9   FLET  WI-N-FL-01  225970.78  1519654.03      2    35460     SNENWIF1
# 10   ILT  WI-N-FL-01  221398.40  1522606.92   6114    41572     SNENWIF1
# 11  FLET  WI-N-FL-01  219060.43  1522518.09   8454   101781     SNENWIF1
# ...

# %%
df_selected_columns = df_csv[['Point', 'Flowline', 'kp', 'node_id']]
df_selected_columns
# Out:
#    Point    Flowline     kp  node_id
# 0   FLET  PR-N-FL-01      2        3
# 1    ILS  PR-N-FL-01   7867     7868
# 2    ILT  PR-N-FL-01   8592     8593
# 3    ILT  PR-N-FL-01  10410    10411
# 4   FLET  PR-N-FL-01  12054   101412
# 5   FLET  PR-N-FL-02      2    12031
# 6    ILT  PR-N-FL-02   8539    20568
# 7    ILT  PR-N-FL-02  10383    22412
# 8   FLET  PR-N-FL-02  11946   101427
# 9   FLET  WI-N-FL-01      2    35460
# 10   ILT  WI-N-FL-01   6114    41572
# 11  FLET  WI-N-FL-01   8454   101781
# 12  FLET  GL-N-FL-01      2    23975
# 13   ILT  GL-N-FL-01   7468    31441
# 14   ILT  GL-N-FL-01   8193    32166
# 15   ILT  GL-N-FL-01   9826    33799
# 16  FLET  GL-N-FL-01  11474   102707
# 17  FLET  PR-S-FL-01      2    43909
# 18   ILT  PR-S-FL-01   8476    52383
# 19   ILT  PR-S-FL-01   9276    53183
# 20  FLET  PR-S-FL-01  13115   102684
# 21  FLET  PR-S-FL-02      4    56449
# 22   ILT  PR-S-FL-02   1418    57863
# 23   ILT  PR-S-FL-02   2855    59300
# ...
